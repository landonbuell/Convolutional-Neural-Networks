# %%
"""
Landon Buell
Visualize Results of Experiment
Number Clf v4
13 April 2020
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

neurons = np.array([20,40,60,80,100,120])

frame = pd.read_csv('model_analysis.csv',index_col=0)
frame.head(10)
# Out:
#                                             train time min  train time max  \
# single_layer_models_control_v1_20                 5.296875       52.296875
# single_layer_models_control_v1_40                 5.734375       72.812500
# single_layer_models_control_v1_60                10.468750       73.484375
# single_layer_models_control_v1_80                11.015625      105.609375
# single_layer_models_control_v1_100               32.187500      168.796875
# single_layer_models_control_v1_120               58.218750      149.171875
# single_layer_models_round_0_decimals_v1_20        5.265625       49.546875
# single_layer_models_round_0_decimals_v1_40        6.328125       78.484375
# single_layer_models_round_0_decimals_v1_60       13.953125       74.937500
# single_layer_models_round_0_decimals_v1_80       14.437500       95.078125
#
#                                             train time avg  loss value min  \
# ...

# %%
# Single Layer Models
single_controls = frame.iloc[0:6]
single_round_v1 = frame.iloc[6:12]
single_round_v2 = frame.iloc[12:18]
single_gauss_v1 = frame.iloc[18:24]
# Double Layer Models
double_controls = frame.iloc[24:30]
double_round_v1 = frame.iloc[30:36]
double_round_v2 = frame.iloc[36:42]
double_gauss_v1 = frame.iloc[42:48]

# %% [markdown]
# # Single Layer Models

# %% [markdown]
# ## Plot Training Time vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Training Time",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Training Time",size=70,weight='bold')

metric = 'train time avg'
plt.plot(neurons,single_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,single_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,single_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,single_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,120,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Single_traintime.png')
plt.show()

# %% [markdown]
# # Plot Loss Function vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Loss Function Value",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Loss Function Value",size=70,weight='bold')

metric = 'loss value avg'
plt.plot(neurons,single_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,single_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,single_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,single_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,2.5,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Single_lossvalue.png')
plt.show()

# %% [markdown]
# ## Plot Training Iterations vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Iterations to Train",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Iterations to Train",size=70,weight='bold')

metric = 'iterations avg'
plt.plot(neurons,single_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,single_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,single_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,single_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,150,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Single_iterations.png')
plt.show()

# %% [markdown]
# ## Average Precision vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Average Precision Score",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Average Precision Score",size=70,weight='bold')

metric = 'average precision'
plt.plot(neurons,single_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,single_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,single_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,single_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,1,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Single_precisions.png')
plt.show()

# %% [markdown]
# ## Average Recall vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Average Recall Score",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Average Recall Score",size=70,weight='bold')

metric = 'average recall'
plt.plot(neurons,single_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,single_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,single_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,single_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,1,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Single_recalls.png')
plt.show()

# %% [markdown]
# # Double Layer Models

# %% [markdown]
# ## Plot Training Time vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Training Time",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Time to Train [s]",size=70,weight='bold')

metric = 'train time avg'
plt.plot(neurons,double_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,double_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,double_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,double_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,180,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Double_traintime.png')
plt.show()

# %% [markdown]
# # Plot Loss Function vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Loss Function Value",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Loss Function Value",size=70,weight='bold')

metric = 'loss value avg'
plt.plot(neurons,double_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,double_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,double_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,double_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,2.5,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Double_lossvalue.png')
plt.show()

# %% [markdown]
# ## Plot Training Iterations vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Iterations to Train",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Iterations to Train",size=70,weight='bold')

metric = 'iterations avg'
plt.plot(neurons,double_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,double_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,double_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,double_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,180,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Double_iterations.png')
plt.show()

# %% [markdown]
# ## Average Precision vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Average Precision Score",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Average Precision Score",size=70,weight='bold')

metric = 'average precision'
plt.plot(neurons,double_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,double_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,double_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,double_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,1,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Double_precisions.png')
plt.show()

# %% [markdown]
# ## Average Recall vs. Neurons / Layer

# %%
plt.figure(figsize=(20,16))
#plt.title("Average Recall Score",size=80,weight='bold')
plt.xlabel("Neurons/Layer",size=70,weight='bold')
plt.ylabel("Average Recall Score",size=70,weight='bold')

metric = 'average recall'
plt.plot(neurons,double_controls[metric],
         linestyle='--',marker='o',markersize=20,label='Control')
plt.plot(neurons,double_round_v1[metric],
         linestyle='--',marker='d',markersize=20,label='Round 50%')
plt.plot(neurons,double_round_v2[metric],
         linestyle='--',marker='s',markersize=20,label='Round 100%')
plt.plot(neurons,double_gauss_v1[metric],
         linestyle='--',marker='v',markersize=20,label='Noise 50%')

plt.vlines(0,0,1,color='black')
plt.hlines(0,0,140,color='black')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()
plt.legend(loc='center right',fontsize=30)
plt.tight_layout()
plt.savefig('Double_recalls.png')
plt.show()
